# %% [markdown]
# ##📌 Extracción

# %%
import requests
import pandas as pd

url = "https://raw.githubusercontent.com/Akiri12/Telecom_X_Alura/refs/heads/main/TelecomX_Data.json"
response = requests.get(url)
data = response.json()
df = pd.DataFrame(data)
df

print("Primeras filas del dataset:")
display(df.head())
# Out:
# Primeras filas del dataset:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# ...

# %%
# Información general
print("\nInformación del dataset:")
df.info()
# Out:
# Información del dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB

# %%
# Estadísticas descriptivas
print("\nEstadísticas descriptivas:")
display(df.describe())
# Out:
# Estadísticas descriptivas:
#         customerID Churn                                           customer  \
# count         7267  7267                                               7267
# unique        7267     3                                                891
# top     9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# freq             1  5174                                                223
#
#                                                  phone  \
# count                                             7267
# unique                                               3
# top     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# freq                                              3495
#
#                                                  internet  \
# count                                                7267
# unique                                                129
# top     {'InternetService': 'No', 'OnlineSecurity': 'N...
# ...

# %%
# Columnas disponibles
print("\nColumnas del dataset:")
print(df.columns.tolist())
# Out:
# Columnas del dataset:
# ['customerID', 'Churn', 'customer', 'phone', 'internet', 'account']

# %% [markdown]
# El archivo .JSON tiene varios objetos anidados en varias columnas, por lo que procedemos a mostrarlos y almacenarlos en un nuevo *dataframe* llamado df_final.

# %%
import pandas as pd
df_final = pd.json_normalize(data)
df_final
# Out:
#       customerID Churn customer.gender  customer.SeniorCitizen  \
# 0     0002-ORFBO    No          Female                       0
# 1     0003-MKNFE    No            Male                       0
# 2     0004-TLHLJ   Yes            Male                       0
# 3     0011-IGKFF   Yes            Male                       1
# 4     0013-EXCHZ   Yes          Female                       1
# ...          ...   ...             ...                     ...
# 7262  9987-LUTYD    No          Female                       0
# 7263  9992-RRAMN   Yes            Male                       0
# 7264  9992-UJOEL    No            Male                       0
# 7265  9993-LHIEB    No            Male                       0
# 7266  9995-HOTOH    No            Male                       0
#
#      customer.Partner customer.Dependents  customer.tenure phone.PhoneService  \
# 0                 Yes                 Yes                9                Yes
# ...

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerID                 7267 non-null   object
#  1   Churn                      7267 non-null   object
#  2   customer.gender            7267 non-null   object
#  3   customer.SeniorCitizen     7267 non-null   int64
#  4   customer.Partner           7267 non-null   object
#  5   customer.Dependents        7267 non-null   object
#  6   customer.tenure            7267 non-null   int64
#  7   phone.PhoneService         7267 non-null   object
#  8   phone.MultipleLines        7267 non-null   object
#  9   internet.InternetService   7267 non-null   object
#  10  internet.OnlineSecurity    7267 non-null   object
#  11  internet.OnlineBackup      7267 non-null   object
#  12  internet.DeviceProtection  7267 non-null   object
# ...

# %% [markdown]
# Explicación de las columnas y valores únicos del dataset TelecomX
#
# ---
#
# *Customer*:
#
# 1. **gender**: Género del cliente.
#    - `'Female'`: Mujer
#    - `'Male'`: Hombre
#
# 2. **SeniorCitizen**: Indica si el cliente es adulto mayor.
#    - `0`: No es adulto mayor (< 65 años)
#    - `1`: Es adulto mayor (≥ 65 años)
#
# 3. **Partner**: Indica si el cliente tiene pareja.
#    - `'Yes'`: Tiene pareja
#    - `'No'`: No tiene pareja
#
# 4. **Dependents**: Indica si el cliente tiene personas a su cargo (hijos, familiares).
#    - `'Yes'`: Tiene dependientes
#    - `'No'`: No tiene dependientes
#
# 5. **tenure**: Tiempo (en meses) que el cliente lleva con la compañía.
#    - Valores enteros desde 0 hasta más de 70 meses, indicando antigüedad.
#
# ---
#
# *Phone*:
#
# 1. **PhoneService**: Indica si el cliente tiene contratado servicio telefónico fijo con la compañía.
#    - `'Yes'`: Tiene servicio telefónico
#    - `'No'`: No tiene servicio telefónico
#
# 2. **MultipleLines**: Indica si el cliente tiene múltiples líneas telefónicas bajo el mismo contrato (aplica solo si PhoneService es `'Yes'`).
#    - `'No'`: Solo una línea telefónica
#    - `'Yes'`: Más de una línea telefónica
#    - `'No phone service'`: No tiene servicio telefónico (equivale a PhoneService = 'No')
#
# ---
#
# *Internet*:
#
# 1. **InternetService**: Tipo de servicio de internet contratado.
#    - `'DSL'`: Servicio por línea DSL
#    - `'Fiber optic'`: Servicio por fibra óptica
#    - `'No'`: No tiene servicio de internet
#
# 2. **OnlineSecurity**: Servicio adicional de seguridad en línea.
#    - `'Yes'`: Tiene contratado
#    - `'No'`: No tiene contratado
#    - `'No internet service'`: No tiene internet (por tanto, no aplica)
#
# 3. **OnlineBackup**: Servicio adicional de respaldo en línea (backup).
#    - `'Yes'`: Tiene contratado
#    - `'No'`: No tiene contratado
#    - `'No internet service'`: No tiene internet
#
# 4. **DeviceProtection**: Servicio adicional de protección para dispositivos (antivirus, seguro, etc).
#    - `'Yes'`: Tiene contratado
#    - `'No'`: No tiene contratado
#    - `'No internet service'`: No tiene internet
#
# 5. **TechSupport**: Servicio de soporte técnico premium.
#    - `'Yes'`: Tiene contratado
#    - `'No'`: No tiene contratado
#    - `'No internet service'`: No tiene internet
#
# 6. **StreamingTV**: Servicio de televisión por streaming.
#    - `'Yes'`: Tiene contratado
#    - `'No'`: No tiene contratado
#    - `'No internet service'`: No tiene internet
#
# 7. **StreamingMovies**: Servicio de películas por streaming.
#    - `'Yes'`: Tiene contratado
#    - `'No'`: No tiene contratado
#    - `'No internet service'`: No tiene internet
#
# ---
#
# *Account*:
#
# 1. **Contract**: Tipo de contrato del cliente.
#    - `'One year'`: Contrato de un año
#    - `'Month-to-month'`: Contrato mes a mes (sin compromiso a largo plazo)
#    - `'Two year'`: Contrato de dos años
#
# 2. **PaperlessBilling**: Indica si el cliente recibe facturas electrónicas (sin papel).
#    - `'Yes'`: Factura electrónica
#    - `'No'`: Factura en papel
#
# 3. **PaymentMethod**: Método que usa el cliente para pagar sus facturas.
#    - `'Mailed check'`: Pago mediante cheque enviado por correo
#    - `'Electronic check'`: Pago electrónico mediante cheque
#    - `'Credit card (automatic)'`: Pago automático con tarjeta de crédito
#    - `'Bank transfer (automatic)'`: Pago automático mediante transferencia bancaria
#
# 4. **Charges.Monthly**: Monto mensual que paga el cliente (en moneda local o USD).
#
# 5. **Charges.Total**: Monto total acumulado que ha pagado el cliente desde el inicio del servicio (puede estar en formato texto).

# %% [markdown]
# #🔧 Transformación

# %%
# Verifique si hay valores únicos en cada columna
for col in df_final.columns:
  print(f"valores únicos en la columna'{col}': {df_final[col].nunique()}")
  if df_final[col].nunique() < 50: # Imprima los valores solamente si no hay muchos
    print(df_final[col].unique())
    print('_' * 60)  # Línea divisoria para mejor visualización
# Out:
# valores únicos en la columna'customerID': 7267
# valores únicos en la columna'Churn': 3
# ['No' 'Yes' '']
# ____________________________________________________________
# valores únicos en la columna'customer.gender': 2
# ['Female' 'Male']
# ____________________________________________________________
# valores únicos en la columna'customer.SeniorCitizen': 2
# [0 1]
# ____________________________________________________________
# valores únicos en la columna'customer.Partner': 2
# ['Yes' 'No']
# ____________________________________________________________
# valores únicos en la columna'customer.Dependents': 2
# ['Yes' 'No']
# ____________________________________________________________
# valores únicos en la columna'customer.tenure': 73
# valores únicos en la columna'phone.PhoneService': 2
# ['Yes' 'No']
# ____________________________________________________________
# valores únicos en la columna'phone.MultipleLines': 3
# ['No' 'Yes' 'No phone service']
# ...

# %% [markdown]
# Observamos que en Churn hay tres categorías ("Yes", "No" y *strings* vacíos), por lo que es necesario hacer una limpieza en los datos.

# %%
#Duplicados
print("Numero de duplicados", df_final.duplicated().sum())
# Out:
# Numero de duplicados 0

# %%
# Nulos
print("Numero de Nulos", df_final.isnull().sum())
# Out:
# Numero de Nulos customerID                   0
# Churn                        0
# customer.gender              0
# customer.SeniorCitizen       0
# customer.Partner             0
# customer.Dependents          0
# customer.tenure              0
# phone.PhoneService           0
# phone.MultipleLines          0
# internet.InternetService     0
# internet.OnlineSecurity      0
# internet.OnlineBackup        0
# internet.DeviceProtection    0
# internet.TechSupport         0
# internet.StreamingTV         0
# internet.StreamingMovies     0
# account.Contract             0
# account.PaperlessBilling     0
# account.PaymentMethod        0
# account.Charges.Monthly      0
# account.Charges.Total        0
# dtype: int64

# %%
# Vacíos o en blanco
df_final.apply(lambda x: x.astype(str).str.strip() == '').sum()
# Out:
# customerID                     0
# Churn                        224
# customer.gender                0
# customer.SeniorCitizen         0
# customer.Partner               0
# customer.Dependents            0
# customer.tenure                0
# phone.PhoneService             0
# phone.MultipleLines            0
# internet.InternetService       0
# internet.OnlineSecurity        0
# internet.OnlineBackup          0
# internet.DeviceProtection      0
# internet.TechSupport           0
# internet.StreamingTV           0
# internet.StreamingMovies       0
# account.Contract               0
# account.PaperlessBilling       0
# account.PaymentMethod          0
# account.Charges.Monthly        0
# account.Charges.Total         11
# dtype: int64

# %%
# Filtrar las filas donde 'account.Charges.Total' está vacía o tiene solo espacios
filas_vacias = df_final[df_final['account.Charges.Total'].astype(str).str.strip() == '']

# Mostrar las filas
print(filas_vacias)
# Out:
#       customerID Churn customer.gender  customer.SeniorCitizen  \
# 975   1371-DWPAZ    No          Female                       0
# 1775  2520-SGTTA    No          Female                       0
# 1955  2775-SEFEE    No            Male                       0
# 2075  2923-ARZLG    No            Male                       0
# 2232  3115-CZMZD    No            Male                       0
# 2308  3213-VVOLG    No            Male                       0
# 2930  4075-WKNIU    No          Female                       0
# 3134  4367-NUYAO    No            Male                       0
# 3203  4472-LVYGI    No          Female                       0
# 4169  5709-LVOEQ    No          Female                       0
# 5599  7644-OMVMY    No            Male                       0
#
#      customer.Partner customer.Dependents  customer.tenure phone.PhoneService  \
# 975               Yes                 Yes                0                 No
# ...

# %% [markdown]
# Se puede ver que *tenure* es 0 en todos los espacios vacíos, por lo que en vez de NaN lo reemplazamos por 0, ya que no tiene antigüedad.

# %%
# Reemplazar cadenas vacías o con solo espacios por NaN
df_final['account.Charges.Total'] = df_final['account.Charges.Total'].astype(str).str.strip().replace('', pd.NA)

# Convertir la columna a numérica (si no lo es ya), forzando errores a NaN
df_final['account.Charges.Total'] = pd.to_numeric(df_final['account.Charges.Total'], errors='coerce')

# Reemplazar NaN por 0
df_final['account.Charges.Total'] = df_final['account.Charges.Total'].fillna(0)

df_final['account.Charges.Total'].isna().sum()  # Debería dar 0
# Out:
# np.int64(0)

# %% [markdown]
# Procedemos a analizar qué hacer con los strings vacíos en Churn

# %%
# Filtrar filas donde Churn está vacío
filas_vacias = df_final[df_final['Churn'] == ""]

# Seleccionar 10 filas al azar
muestra_aleatoria = filas_vacias.sample(n=10, random_state=33)

# Mostrar resultado
print(muestra_aleatoria)
# Out:
#       customerID Churn customer.gender  customer.SeniorCitizen  \
# 2690  3728-SDRGN                  Male                       0
# 4578  6271-PRTUU                Female                       0
# 368   0530-HBKHZ                Female                       1
# 6346  8732-BBLMG                Female                       0
# 4072  5570-ZGMEU                  Male                       0
# 973   1370-AQYEM                  Male                       0
# 6406  8793-IZZRV                  Male                       0
# 6500  8933-FSHGW                Female                       1
# 590   0840-JCCUW                Female                       0
# 175   0274-VVQOQ                  Male                       1
#
#      customer.Partner customer.Dependents  customer.tenure phone.PhoneService  \
# 2690               No                 Yes                1                Yes
# 4578              Yes                 Yes               28                Yes
# ...

# %%
# Total de filas
total_filas = len(df_final)

# Número de valores nulos en la columna "Churn" (dato conocido)
nulos_churn = 224

# Calcular porcentaje
porcentaje_nulos = (nulos_churn / total_filas) * 100

# Mostrar resultado
print(f"Total de filas: {total_filas}")
print(f"Strings vacíos en 'Churn': {nulos_churn}")
print(f"Porcentaje de strings vacíos en 'Churn': {porcentaje_nulos:.2f}%")
# Out:
# Total de filas: 7267
# Strings vacíos en 'Churn': 224
# Porcentaje de strings vacíos en 'Churn': 3.08%

# %% [markdown]
# Dado que el porcentaje de *strings* vacíos en el dataframe es bajo y no observamos a simple vista una relación entre los datos, lo eliminamos para hacer el análisis sin que esto afecte mayormente el resultado.

# %%
# Eliminando las columnas de Churn

df_final = df_final[df_final['Churn'].str.strip() != '']
print("Número de filas después de eliminar las vacías en 'Churn':", len(df_final))
# Out:
# Número de filas después de eliminar las vacías en 'Churn': 7043

# %%
# Vacíos o en blanco
df_final.apply(lambda x: x.astype(str).str.strip() == '').sum()
# Out:
# customerID                   0
# Churn                        0
# customer.gender              0
# customer.SeniorCitizen       0
# customer.Partner             0
# customer.Dependents          0
# customer.tenure              0
# phone.PhoneService           0
# phone.MultipleLines          0
# internet.InternetService     0
# internet.OnlineSecurity      0
# internet.OnlineBackup        0
# internet.DeviceProtection    0
# internet.TechSupport         0
# internet.StreamingTV         0
# internet.StreamingMovies     0
# account.Contract             0
# account.PaperlessBilling     0
# account.PaymentMethod        0
# account.Charges.Monthly      0
# account.Charges.Total        0
# dtype: int64

# %% [markdown]
# Creando la columna "Cuentas_Diarias".
#
# $\text{Cuentas diarias}=\dfrac{\text{facturación mensual}}{30}$

# %%
df_final = df_final.copy()
df_final["Cuentas_Diarias"] = (df_final["account.Charges.Monthly"] / 30).round(2) # Solo 2 decimales

# %%
df_final.head()
# Out:
#    customerID Churn customer.gender  customer.SeniorCitizen customer.Partner  \
# 0  0002-ORFBO    No          Female                       0              Yes
# 1  0003-MKNFE    No            Male                       0               No
# 2  0004-TLHLJ   Yes            Male                       0               No
# 3  0011-IGKFF   Yes            Male                       1              Yes
# 4  0013-EXCHZ   Yes          Female                       1              Yes
#
#   customer.Dependents  customer.tenure phone.PhoneService phone.MultipleLines  \
# 0                 Yes                9                Yes                  No
# 1                  No                9                Yes                 Yes
# 2                  No                4                Yes                  No
# 3                  No               13                Yes                  No
# 4                  No                3                Yes                  No
#
# ...

# %% [markdown]
# Hay varios objetos con valores "Yes" y "No", los convertimos a binarios para facilitar su estudio posterior.

# %%
# Detectar columnas que contienen únicamente Yes/No (además de posibles NaN)
cols_yes_no = [
    col for col in df_final.columns
    if set(df_final[col].dropna().unique()) <= {"Yes", "No"}
]

# Reemplazar solo en esas columnas
df_final[cols_yes_no] = df_final[cols_yes_no].replace({'Yes': 1, 'No': 0})
# Out:
# /tmp/ipython-input-1008355961.py:8: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_final[cols_yes_no] = df_final[cols_yes_no].replace({'Yes': 1, 'No': 0})

# %%
df_final.head()
# Out:
#    customerID  Churn customer.gender  customer.SeniorCitizen  \
# 0  0002-ORFBO      0          Female                       0
# 1  0003-MKNFE      0            Male                       0
# 2  0004-TLHLJ      1            Male                       0
# 3  0011-IGKFF      1            Male                       1
# 4  0013-EXCHZ      1          Female                       1
#
#    customer.Partner  customer.Dependents  customer.tenure  phone.PhoneService  \
# 0                 1                    1                9                   1
# 1                 0                    0                9                   1
# 2                 0                    0                4                   1
# 3                 1                    0               13                   1
# 4                 1                    0                3                   1
#
#   phone.MultipleLines internet.InternetService  ... internet.DeviceProtection  \
# ...

# %%
df_final.info()

# Verifique si hay valores únicos en cada columna
for col in df_final.columns:
  print(f"valores únicos en la columna'{col}': {df_final[col].nunique()}")
  if df_final[col].nunique() < 50: # Imprima los valores solamente si no hay muchos
    print(df_final[col].unique())
    print('_' * 60)  # Línea divisoria para mejor visualización
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 0 to 7266
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerID                 7043 non-null   object
#  1   Churn                      7043 non-null   int64
#  2   customer.gender            7043 non-null   object
#  3   customer.SeniorCitizen     7043 non-null   int64
#  4   customer.Partner           7043 non-null   int64
#  5   customer.Dependents        7043 non-null   int64
#  6   customer.tenure            7043 non-null   int64
#  7   phone.PhoneService         7043 non-null   int64
#  8   phone.MultipleLines        7043 non-null   object
#  9   internet.InternetService   7043 non-null   object
#  10  internet.OnlineSecurity    7043 non-null   object
#  11  internet.OnlineBackup      7043 non-null   object
#  12  internet.DeviceProtection  7043 non-null   object
# ...

# %% [markdown]
# #📊 Carga y análisis

# %%
# Guardar DataFrame en CSV
df_final.to_csv("TelecomX_Data_Limpio.csv", index=False, encoding="utf-8")

print("Archivo guardado como 'TelecomX_Data_Limpio.csv'")
# Out:
# Archivo guardado como 'TelecomX_Data_Limpio.csv'

# %% [markdown]
# Haciendo un análisis descriptivo de los datos

# %%
# Identificar columnas binarias (solo contienen 0, 1 o NaN)
binarias = [
    col for col in df_final.columns
    if df_final[col].dropna().isin([0, 1]).all()
]

# Filtrar solo columnas numéricas que no sean binarias
num_cols = df_final.select_dtypes(include=['number']).columns
num_no_bin = [col for col in num_cols if col not in binarias]

# Análisis descriptivo con 1 decimal
desc = df_final[num_no_bin].describe().round(1)

print("Columnas binarias excluidas:", binarias)
desc
# Out:
# Columnas binarias excluidas: ['Churn', 'customer.SeniorCitizen', 'customer.Partner', 'customer.Dependents', 'phone.PhoneService', 'account.PaperlessBilling']
#        customer.tenure  account.Charges.Monthly  account.Charges.Total  \
# count           7043.0                   7043.0                 7043.0
# mean              32.4                     64.8                 2279.7
# std               24.6                     30.1                 2266.8
# min                0.0                     18.2                    0.0
# 25%                9.0                     35.5                  398.6
# 50%               29.0                     70.4                 1394.6
# 75%               55.0                     89.8                 3786.6
# max               72.0                    118.8                 8684.8
#
#        Cuentas_Diarias
# count           7043.0
# mean               2.2
# std                1.0
# min                0.6
# 25%                1.2
# 50%                2.3
# ...

# %%
import matplotlib.pyplot as plt

# Cargar CSV limpio
df_final = pd.read_csv("TelecomX_Data_Limpio.csv")

# Conteo de valores
churn_counts = df_final['Churn'].value_counts().sort_index()

# Etiquetas y colores
#labels = ['No', 'Yes']
colors = ['skyblue', 'salmon']

# Gráfico circular
plt.pie(
    churn_counts,
    labels=labels,
    autopct='%1.1f%%',
    startangle=90,
    colors=colors,
    wedgeprops={'edgecolor': 'black'}
)

# Añadir título
plt.title('Porcentaje de abandono de clientes')

# Añadir leyenda explicativa
plt.legend(
    labels=[
        "Cliente retenido",
        "Cliente que abandonó"
    ],
    loc="upper right",
    bbox_to_anchor=(1.3, 1)  # Mover la caja a la derecha
)

plt.axis('equal')  # Mantener círculo perfecto
plt.show()

# %%
# Agrupar datos por contrato y churn
contract_churn = df_final.groupby(['account.Contract', 'Churn']).size().unstack(fill_value=0)

# Mapeo de etiquetas en español
contract_labels = {
    'Month-to-month': 'Mes a mes',
    'One year': '1 año',
    'Two year': '2 años'
}
contract_churn.index = contract_churn.index.map(contract_labels)

# Colores
colors = ['skyblue', 'salmon']

# Gráfico de barras apiladas
contract_churn.plot(
    kind='bar',
    stacked=True,
    color=colors,
    figsize=(8, 5)
)

# Etiquetas y título
plt.xlabel('Duración del contrato')
plt.ylabel('Cantidad de clientes')
plt.title('Abandono por tipo de contrato')
plt.legend(['Cliente retenido', 'Cliente que abandonó'], loc='upper right')

plt.xticks(rotation=0)
plt.show()

# %%
import matplotlib.pyplot as plt

# Agrupar datos por InternetService y Churn
internet_churn = df_final.groupby(['internet.InternetService', 'Churn']).size().unstack(fill_value=0)

# Ordenar por total de clientes en orden descendente
internet_churn = internet_churn.loc[internet_churn.sum(axis=1).sort_values(ascending=False).index]

# Colores
colors = ['skyblue', 'salmon']

# Gráfico de barras apiladas
internet_churn.plot(
    kind='bar',
    stacked=True,
    color=colors,
    figsize=(8, 5)
)

# Etiquetas y título
plt.xlabel('Tipo de servicio de internet')
plt.ylabel('Cantidad de clientes')
plt.title('Abandono por tipo de servicio de internet')
plt.legend(['Cliente retenido', 'Cliente que abandonó'], loc='upper right')

plt.xticks(rotation=0)
plt.show()

# %%
import matplotlib.pyplot as plt

# Agrupar datos por InternetService y Churn
internet_churn = df_final.groupby(['internet.StreamingTV', 'Churn']).size().unstack(fill_value=0)

# Ordenar por total de clientes en orden descendente
internet_churn = internet_churn.loc[internet_churn.sum(axis=1).sort_values(ascending=False).index]

# Colores
colors = ['skyblue', 'salmon']

# Gráfico de barras apiladas
internet_churn.plot(
    kind='bar',
    stacked=True,
    color=colors,
    figsize=(8, 5)
)

# Etiquetas y título
plt.xlabel('Tipo de Streaming TV')
plt.ylabel('Cantidad de clientes')
plt.title('Abandono por tipo de Streaming TV')
plt.legend(['Cliente retenido', 'Cliente que abandonó'], loc='upper right')

plt.xticks(rotation=0)
plt.show()

# %%
# Agrupar por método de pago y Churn
payment_churn = df_final.groupby(['account.PaymentMethod', 'Churn']).size().unstack(fill_value=0)

# Ordenar por total de clientes en orden descendente
payment_churn = payment_churn.loc[payment_churn.sum(axis=1).sort_values(ascending=False).index]

# Gráfico de barras horizontales apiladas
payment_churn.plot(
    kind='barh',
    stacked=True,
    color=['skyblue', 'salmon'],
    figsize=(9, 5)
)

# Etiquetas y título
plt.ylabel('Método de pago')
plt.xlabel('Cantidad de clientes')
plt.title('Abandono por método de pago')
plt.legend(['Cliente retenido', 'Cliente que abandonó'], loc='lower right')

plt.gca().invert_yaxis()  # Poner el mayor arriba
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar CSV limpio
df_final = pd.read_csv("TelecomX_Data_Limpio.csv")

# Agrupar por género y churn
customer_gender_churn = df_final.groupby(['customer.gender', 'Churn']).size().unstack(fill_value=0)

# Gráfico de barras agrupadas
ax = customer_gender_churn.plot(
    kind='bar',
    color=['skyblue', 'salmon'],
    figsize=(7, 5)
)

# Etiquetas y título
plt.xlabel('Género')
plt.ylabel('Cantidad de clientes')
plt.title('Abandono por género')

# Leyenda fuera del gráfico
plt.legend(
    ['Cliente retenido', 'Cliente que abandonó'],
    loc='center left',
    bbox_to_anchor=(1, 0.5)
)

plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# Columnas disponibles
print("\nColumnas del dataset:")
print(df_final.columns.tolist())
# Out:
# Columnas del dataset:
# ['customerID', 'Churn', 'customer.gender', 'customer.SeniorCitizen', 'customer.Partner', 'customer.Dependents', 'customer.tenure', 'phone.PhoneService', 'phone.MultipleLines', 'internet.InternetService', 'internet.OnlineSecurity', 'internet.OnlineBackup', 'internet.DeviceProtection', 'internet.TechSupport', 'internet.StreamingTV', 'internet.StreamingMovies', 'account.Contract', 'account.PaperlessBilling', 'account.PaymentMethod', 'account.Charges.Monthly', 'account.Charges.Total', 'Cuentas_Diarias']

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Asegurar que Churn sea binario si es necesario
if df_final['Churn'].dtype != 'int' and df_final['Churn'].dtype != 'float':
    df_final['Churn'] = df_final['Churn'].map({'Yes': 1, 'No': 0})

# Calcular el máximo de tenure
max_tenure = df_final['customer.tenure'].max()

# Crear histograma con barras más anchas
plt.figure(figsize=(12, 5))  # Más ancho
bins = range(0, max_tenure + 2, 2)  # bins cada 2 meses para más grosor

plt.hist(
    [df_final[df_final['Churn'] == 0]['customer.tenure'],
     df_final[df_final['Churn'] == 1]['customer.tenure']],
    bins=bins,
    label=['Cliente retenido', 'Cliente que abandonó'],
    color=['skyblue', 'salmon'],
    alpha=0.8
)

# Ajustar límites para eliminar espacio extra
plt.xlim(0, max_tenure)

# Etiquetas y título
plt.xlabel('Tenure (meses)')
plt.ylabel('Cantidad de clientes')
plt.title('Histograma de abandono por Tenure (tiempo de permanencia)')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
# Agrupar por tenure y Churn
df_grouped = df_final.groupby(['customer.tenure', 'Churn']).size().unstack(fill_value=0)

# Calcular el % de churn por tenure (1 = hizo churn)
df_grouped['churn_rate'] = (df_grouped[1] / df_grouped.sum(axis=1)) * 100

# Mostrar el resultado
print(df_grouped[['churn_rate']])
# Out:
# Churn            churn_rate
# customer.tenure
# 0                  0.000000
# 1                 61.990212
# 2                 51.680672
# 3                 47.000000
# 4                 47.159091
# ...                     ...
# 68                 9.000000
# 69                 8.421053
# 70                 9.243697
# 71                 3.529412
# 72                 1.657459
#
# [73 rows x 1 columns]

# %%
import plotly.express as px

fig = px.line(
    df_grouped.reset_index(),
    x='customer.tenure',
    y='churn_rate',
    markers=True,
    title='Tasa de Abandono (%) por Antigüedad'
)

# Cambiar colores
fig.update_traces(
    line=dict(color='skyblue'),
    marker=dict(color='salmon')
)

# Fondo blanco
fig.update_layout(
    paper_bgcolor='white',
    plot_bgcolor='white',
    width=1000,
    height=600
)

# Quitar espacios antes del 0 en ambos ejes
fig.update_xaxes(
    range=[0, df_grouped.reset_index()['customer.tenure'].max()],
    showline=True,
    linecolor='black',
    linewidth=1
)
fig.update_yaxes(
    range=[0, df_grouped['churn_rate'].max()],
    showline=True,
    linecolor='black',
    linewidth=1
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px

# Convertir Churn a string para control exacto
df_final['Churn_str'] = df_final['Churn'].astype(str)

color_map = {
    '0': 'skyblue',
    '1': 'salmon'
}

fig = px.scatter(
    df_final,
    x="customer.tenure",
    y="account.Charges.Monthly",
    color="Churn_str",
    title="Antigüedad vs Cargos mensuales por Abandono",
    color_discrete_map=color_map,
    labels={"Churn_str": "Estado del cliente"},
    category_orders={"Churn_str": ["0", "1"]},
)

# Cambiar etiquetas en la leyenda manualmente
fig.for_each_trace(
    lambda trace: trace.update(name="Retención" if trace.name == "0" else "Abandono")
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px

# Convertir Churn a string para control exacto
df_final['Churn_str'] = df_final['Churn'].astype(str)

color_map = {
    '0': 'skyblue',
    '1': 'salmon'
}

fig = px.box(
    df_final,
    x='Churn_str',
    y='account.Charges.Monthly',
    color='Churn_str',
    color_discrete_map=color_map,
    labels={'Churn_str': 'Estado del cliente', 'account.Charges.Monthly': 'Cargos Mensuales'},
    category_orders={'Churn_str': ['0', '1']},
    title='Distribución de Cargos Mensuales según Estado del Cliente'
)

# Cambiar etiquetas en la leyenda manualmente
fig.for_each_trace(
    lambda trace: trace.update(name='Retención' if trace.name == '0' else 'Abandono')
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #📄Informe final

# %% [markdown]
# Se realizó un ETL sobre los datos de clientes, servicios e información de contrato, aplicando limpieza de datos, normalización de columnas binarias, corrección de valores faltantes y cálculo de métricas como cargos diarios. Durante la limpieza se detectaron inconsistencias: 224 filas de Churn con strings vacíos fueron eliminadas (3,08% del total), y 11 filas con cargos totales NaN fueron corregidas, ya que la información podía inferirse.
#
# Del análisis de los datos limpios, respaldado por los gráficos generados (histograma de churn por tenure, línea de tasa de abandono por antigüedad, boxplots y scatter de cargos mensuales, y gráficos categóricos por género, método de pago, streaming, servicio de internet y tipo de contrato), se concluye que el abandono total de clientes alcanza el 26,5%, concentrándose principalmente en contratos mes a mes, clientes con fibra óptica y pagos electrónicos mediante cheques. La mayor tasa de abandono ocurre durante los primeros 6 meses de antigüedad, disminuyendo significativamente a medida que los clientes permanecen más tiempo. Los clientes que abandonaron presentaron una mediana de cargos mensuales de 79,7 frente a 64,4 de los clientes retenidos; el 25% de los clientes con menores cargos mensuales que abandonó pagó 56,2 frente a 18,3 de los retenidos. En promedio, los cargos mensuales fueron de 64,8, los cargos totales de 2.279,7 y el tenure promedio de 32,4 meses. No se observaron diferencias significativas por género ni por consumo de Streaming TV.
#
# Estos hallazgos, obtenidos a partir de los gráficos y métricas descriptivas, pueden guiar estrategias de retención, priorizando clientes con mayor riesgo de abandono y ajustando incentivos según tipo de contrato, tenure, modalidad de pago y cargos mensuales.
